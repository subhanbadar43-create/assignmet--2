# %%
amount = int(input("enter your bill amount"))
if amount >= 20000:
    surcharge = amount * 0.10
    finalbill = amount + surcharge
    print("your final bill is:",finalbill)
else:
    print("you are not valid for surcharge.")
# Out:
# enter your bill amount20000
# your final bill is: 22000.0
